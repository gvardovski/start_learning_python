# %%
import pandas as pd
import pandas_ta as ta
import vectorbt as vbt

df = pd.read_csv("MSFT_1hour.csv", index_col="Time")
df.index = pd.to_datetime(df.index)
pf_rsi = {}
for i in ['7','14','21']:
    df[f'RSI_{i}'] = ta.rsi(df['Close'], length=int(i))

    entries = df[f'RSI_{i}'] < 30
    exits = df[f'RSI_{i}'] > 70

    pf = vbt.Portfolio.from_signals(
    entries = entries,
    exits = exits,
    open = df["Open"],
    close = df["Close"],
    high = df["High"],
    low = df["Low"],
    size = df['Volume'],
    size_type ="value",
    fees=0,
    slippage=0,
    init_cash=1000,
    freq ="1hour"
    )
    pf_rsi.update({f'RSI_{i}':pf})

# %%
pf_rsi['RSI_14'].stats()
# Out:
# Start                          2020-01-01 00:00:00+00:00
# End                            2025-09-26 23:00:00+00:00
# Period                                 959 days 06:00:00
# Start Value                                       1000.0
# End Value                                    1900.920296
# Total Return [%]                                90.09203
# Benchmark Return [%]                          223.350333
# Max Gross Exposure [%]                             100.0
# Total Fees Paid                                      0.0
# Max Drawdown [%]                               27.505018
# Max Drawdown Duration                  175 days 06:00:00
# Total Trades                                          41
# Total Closed Trades                                   41
# Total Open Trades                                      0
# Open Trade PnL                                       0.0
# Win Rate [%]                                   68.292683
# Best Trade [%]                                 11.224429
# Worst Trade [%]                                -17.90817
# Avg Winning Trade [%]                           4.437107
# Avg Losing Trade [%]                           -4.103094
# Avg Winning Trade Duration     6 days 02:55:42.857142857
# Avg Losing Trade Duration     18 days 22:18:27.692307692
# Profit Factor                                   2.209662
# Expectancy                                     21.973666
# Sharpe Ratio                                    0.862689
# Calmar Ratio                                    1.006623
# Omega Ratio                                     1.049225
# Sortino Ratio                                   1.258548
# dtype: object

# %%
pf_rsi['RSI_7'].plot()
# Out:
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': '#1f77b4'},
#               'name': 'Close',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'f025bcb1-237a-4e4c-ad7d-a74cbf638b77',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('MzMzMzO7Y0CPwvUoXN9jQNejcD0K32' ... 'A9Ctfjf0AfhetRuOZ/QKjGSzeJ5n9A'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'customdata': {'bdata': ('AAAAAAAAAAC5lwk/nn0ZQAAAAAAAAA' ... 'AAAADwhEBmqTX7TQkbQAAAAAAAAAAA'),
#                              'dtype': 'f8',
#                              'shape': '336, 3'},
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '1',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-up'},
#               'mode': 'markers',
#               'name': 'Buy',
#               'type': 'scatter',
#               'uid': 'fbb38fb8-3875-487a-ad79-c662d2774404',
#               'x': array([Timestamp('2020-01-06 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-07 19:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-10 20:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-15 10:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-16 13:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-23 13:00:00+0000', tz='UTC')],
#                          shape=(336,), dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('PQrXo3CdY0DhehSuR8FjQArXo3A9Km' ... 'AAAACof0BSuB6F6/N/QAAAAAAA/H9A'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'customdata': {'bdata': ('AAAAAAAA8D+5lwk/nn0ZQAAAAAAAAA' ... 'AAAAD4hEBmqTX7TQkbQAAAAAAAAAAA'),
#                              'dtype': 'f8',
#                              'shape': '336, 3'},
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '2',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-down'},
#               'mode': 'markers',
#               'name': 'Sell',
#               'type': 'scatter',
#               'uid': '2b14c715-2db2-4644-85ce-86d0cbed02e8',
#               'x': array([Timestamp('2020-01-07 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-08 16:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-13 20:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-15 14:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-18 08:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 12:00:00+0000', tz='UTC')],
#                          shape=(336,), dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('ZmZmZmbuY0AfhetRuPpjQClcj8L1aG' ... 'gehesDgEBmZmZmZhKAQJqZmZmZ7X9A'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'customdata': {'bdata': ('AAAAAAAAAAAAAAAAAAAAAAAwOxd0Hz' ... 'AAAADgdECA6mLI74s0QBQYqDXheXg/'),
#                              'dtype': 'f8',
#                              'shape': '231, 4'},
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '3',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'opacity': {'bdata': ('MVhQL2O+6D/o872a/4XoP0S/IJ5ej+' ... 'OBgM4q6D+6VVWNiovoP6Qi5+tNRug/'),
#                                      'dtype': 'f8'},
#                          'size': {'bdata': ('kFaq9EsrIEByuf5bqA0fQA2xaZpSRB' ... '1JmLT5HEC/HseN/S0fQGefGeAbmh1A'),
#                                   'dtype': 'f8'},
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Profit',
#               'type': 'scatter',
#               'uid': '7f2a10af-ec3c-426b-ac08-0ab144c4211e',
#               'x': array([Timestamp('2020-01-07 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-08 16:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-13 20:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-10 11:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-15 14:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-18 08:00:00+0000', tz='UTC')],
#                          shape=(231,), dtype=object),
#               'xaxis': 'x2',
#               'y': {'bdata': ('EoM4KoOCkD9C9WZlzUKHP2WOgcf54Y' ... 'DJPcrqbT94/KmQXTiIPxQYqDXheXg/'),
#                     'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'customdata': {'bdata': ('AAAAAAAAFEAAAAAAAAAUQACP6yEDzC' ... 'AAAADwdEAA5EmVLFUYwE8AqNlm0Fy/'),
#                              'dtype': 'f8',
#                              'shape': '105, 4'},
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '4',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'opacity': {'bdata': ('SravUiOy6D/vFp+dUW3rPzL/kUFH2+' ... 'Ggdoyb6D/Qn98Rg77oP/9r0KVmFOg/'),
#                                      'dtype': 'f8'},
#                          'size': {'bdata': ('BCkrsZEHIEA5WGW22P4nQKZ9lNSPfy' ... 'JRCV6LH0AgkiH0qCsgQP116nEBdxxA'),
#                                   'dtype': 'f8'},
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Loss',
#               'type': 'scatter',
#               'uid': '6aff0258-927b-464e-88e3-239fc37f2ff6',
#               'x': array([Timestamp('2020-01-28 12:00:00+0000', tz='UTC'),
#                           Timestamp('2020-02-26 15:00:00+0000', tz='UTC'),
#                           Timestamp('2020-03-10 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-04-22 17:00:00+0000', tz='UTC'),
#                           Timestamp('2020-05-15 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-07-20 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-07-27 21:00:00+0000', tz='UTC'),
#                           Timestamp('2020-08-12 14:00:00+0000', tz='UTC'),
#                           Timestamp('2020-09-09 14:00:00+0000', tz='UTC'),
#                           Timestamp('2020-09-21 19:00:00+0000', tz='UTC'),
#                           Timestamp('2020-10-23 19:00:00+0000', tz='UTC'),
#                           Timestamp('2020-11-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-11-11 16:00:00+0000', tz='UTC'),
#                           Timestamp('2020-11-24 16:00:00+0000', tz='UTC'),
#                           Timestamp('2020-12-11 18:00:00+0000', tz='UTC'),
#                           Timestamp('2021-01-04 09:00:00+0000', tz='UTC'),
#                           Timestamp('2021-01-07 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-01-13 21:00:00+0000', tz='UTC'),
#                           Timestamp('2021-02-26 16:00:00+0000', tz='UTC'),
#                           Timestamp('2021-03-04 15:00:00+0000', tz='UTC'),
#                           Timestamp('2021-03-22 13:00:00+0000', tz='UTC'),
#                           Timestamp('2021-03-26 15:00:00+0000', tz='UTC'),
#                           Timestamp('2021-05-06 19:00:00+0000', tz='UTC'),
#                           Timestamp('2021-05-13 13:00:00+0000', tz='UTC'),
#                           Timestamp('2021-06-04 12:00:00+0000', tz='UTC'),
#                           Timestamp('2021-08-02 08:00:00+0000', tz='UTC'),
#                           Timestamp('2021-08-30 09:00:00+0000', tz='UTC'),
#                           Timestamp('2021-09-22 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-10-01 15:00:00+0000', tz='UTC'),
#                           Timestamp('2021-11-12 00:00:00+0000', tz='UTC'),
#                           Timestamp('2021-11-29 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-12-15 20:00:00+0000', tz='UTC'),
#                           Timestamp('2021-12-21 11:00:00+0000', tz='UTC'),
#                           Timestamp('2022-01-11 00:00:00+0000', tz='UTC'),
#                           Timestamp('2022-01-19 13:00:00+0000', tz='UTC'),
#                           Timestamp('2022-02-15 09:00:00+0000', tz='UTC'),
#                           Timestamp('2022-02-23 09:00:00+0000', tz='UTC'),
#                           Timestamp('2022-03-09 15:00:00+0000', tz='UTC'),
#                           Timestamp('2022-04-12 12:00:00+0000', tz='UTC'),
#                           Timestamp('2022-04-25 18:00:00+0000', tz='UTC'),
#                           Timestamp('2022-05-10 13:00:00+0000', tz='UTC'),
#                           Timestamp('2022-05-13 16:00:00+0000', tz='UTC'),
#                           Timestamp('2022-05-23 13:00:00+0000', tz='UTC'),
#                           Timestamp('2022-06-14 23:00:00+0000', tz='UTC'),
#                           Timestamp('2022-07-01 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-07-14 22:00:00+0000', tz='UTC'),
#                           Timestamp('2022-08-25 08:00:00+0000', tz='UTC'),
#                           Timestamp('2022-08-30 08:00:00+0000', tz='UTC'),
#                           Timestamp('2022-09-02 13:00:00+0000', tz='UTC'),
#                           Timestamp('2022-09-21 13:00:00+0000', tz='UTC'),
#                           Timestamp('2022-10-13 11:00:00+0000', tz='UTC'),
#                           Timestamp('2022-10-28 13:00:00+0000', tz='UTC'),
#                           Timestamp('2022-11-04 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-11-30 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-12-08 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-12-21 00:00:00+0000', tz='UTC'),
#                           Timestamp('2022-12-29 14:00:00+0000', tz='UTC'),
#                           Timestamp('2023-01-09 14:00:00+0000', tz='UTC'),
#                           Timestamp('2023-01-20 14:00:00+0000', tz='UTC'),
#                           Timestamp('2023-02-23 11:00:00+0000', tz='UTC'),
#                           Timestamp('2023-03-29 09:00:00+0000', tz='UTC'),
#                           Timestamp('2023-04-12 12:00:00+0000', tz='UTC'),
#                           Timestamp('2023-06-09 13:00:00+0000', tz='UTC'),
#                           Timestamp('2023-06-22 15:00:00+0000', tz='UTC'),
#                           Timestamp('2023-06-27 13:00:00+0000', tz='UTC'),
#                           Timestamp('2023-07-12 11:00:00+0000', tz='UTC'),
#                           Timestamp('2023-07-25 09:00:00+0000', tz='UTC'),
#                           Timestamp('2023-07-28 14:00:00+0000', tz='UTC'),
#                           Timestamp('2023-08-10 12:00:00+0000', tz='UTC'),
#                           Timestamp('2023-08-21 08:00:00+0000', tz='UTC'),
#                           Timestamp('2023-09-20 12:00:00+0000', tz='UTC'),
#                           Timestamp('2023-09-29 08:00:00+0000', tz='UTC'),
#                           Timestamp('2023-12-05 23:00:00+0000', tz='UTC'),
#                           Timestamp('2024-01-05 15:00:00+0000', tz='UTC'),
#                           Timestamp('2024-02-01 14:00:00+0000', tz='UTC'),
#                           Timestamp('2024-02-14 21:00:00+0000', tz='UTC'),
#                           Timestamp('2024-02-21 22:00:00+0000', tz='UTC'),
#                           Timestamp('2024-03-07 17:00:00+0000', tz='UTC'),
#                           Timestamp('2024-04-01 08:00:00+0000', tz='UTC'),
#                           Timestamp('2024-04-23 13:00:00+0000', tz='UTC'),
#                           Timestamp('2024-05-01 18:00:00+0000', tz='UTC'),
#                           Timestamp('2024-06-04 19:00:00+0000', tz='UTC'),
#                           Timestamp('2024-07-22 13:00:00+0000', tz='UTC'),
#                           Timestamp('2024-07-26 16:00:00+0000', tz='UTC'),
#                           Timestamp('2024-08-07 10:00:00+0000', tz='UTC'),
#                           Timestamp('2024-09-05 13:00:00+0000', tz='UTC'),
#                           Timestamp('2024-09-25 14:00:00+0000', tz='UTC'),
#                           Timestamp('2024-10-04 12:00:00+0000', tz='UTC'),
#                           Timestamp('2024-11-05 14:00:00+0000', tz='UTC'),
#                           Timestamp('2024-11-19 18:00:00+0000', tz='UTC'),
#                           Timestamp('2024-12-24 15:00:00+0000', tz='UTC'),
#                           Timestamp('2025-01-02 11:00:00+0000', tz='UTC'),
#                           Timestamp('2025-01-14 09:00:00+0000', tz='UTC'),
#                           Timestamp('2025-01-28 15:00:00+0000', tz='UTC'),
#                           Timestamp('2025-02-06 00:00:00+0000', tz='UTC'),
#                           Timestamp('2025-02-26 15:00:00+0000', tz='UTC'),
#                           Timestamp('2025-02-28 20:00:00+0000', tz='UTC'),
#                           Timestamp('2025-03-14 14:00:00+0000', tz='UTC'),
#                           Timestamp('2025-04-01 14:00:00+0000', tz='UTC'),
#                           Timestamp('2025-04-08 13:00:00+0000', tz='UTC'),
#                           Timestamp('2025-04-22 16:00:00+0000', tz='UTC'),
#                           Timestamp('2025-07-24 13:00:00+0000', tz='UTC'),
#                           Timestamp('2025-08-11 09:00:00+0000', tz='UTC'),
#                           Timestamp('2025-08-22 14:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 12:00:00+0000', tz='UTC')], dtype=object),
#               'xaxis': 'x2',
#               'y': {'bdata': ('ut0MEVXmjr8HKojlzPyyv7nuWaB+Ap' ... 'X83Yz9ir8jdbF4RYWQv08AqNlm0Fy/'),
#                     'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'legendgroup': '5',
#               'line': {'color': '#7f7f7f'},
#               'name': 'Benchmark',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'aa07079b-4699-4d48-b977-4dd65367c174',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D9mAoxvUh3wPx0A0QEQHf' ... 'KbVAfcCUB+9y4wXd4JQMhv4/023glA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '6',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '208eae6d-98bd-4f8a-80ee-e6b91ef412eb',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQEB'),
#                     'dtype': 'i1'},
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(0, 128, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '6',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1177faa4-de6d-488b-8bba-a0a1f0608bdf',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D8AAAAAAADwPwAAAAAAAP' ... 'pyNn+fC0D/SnI2f58LQP9KcjZ/nwtA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '6',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '665ecd99-f69b-4904-8b0c-6e97831770d5',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQEB'),
#                     'dtype': 'i1'},
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(255, 0, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '6',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '1703d977-496e-49f5-ae34-5a93ac743a0c',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D8AAAAAAADwPwAAAAAAAP' ... 'AAAAAA8D8AAAAAAADwPwAAAAAAAPA/'),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'legendgroup': '7',
#               'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'b3d06a44-a348-4ad9-8171-2118bde7993d',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D8AAAAAAADwPwAAAAAAAP' ... 'pyNn+fC0D/SnI2f58LQP9KcjZ/nwtA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '6',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e100464f-89f1-461f-8cab-59fb2b9e4b87',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQEB'),
#                     'dtype': 'i1'},
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Orders',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trade PnL',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.6527777777777777,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Cumulative Returns',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.3055555555555555,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 960,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.0416666666666667,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 0,
#                            'y1': 0,
#                            'yref': 'y2'},
#                           {'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y3'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 750,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0], 'title': {'text': 'Index'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.6944444444444444, 1.0], 'title': {'text': 'Price'}},
#                'yaxis2': {'anchor': 'x2',
#                           'domain': [0.3472222222222222, 0.6527777777777777],
#                           'tickformat': '.2%',
#                           'title': {'text': 'Trade PnL'}},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 0.3055555555555555], 'title': {'text': 'Cumulative returns'}}}
# })

# %%
import pandas as pd
import pandas_ta as ta
import vectorbt as vbt

df = pd.read_csv("MSFT_1hour.csv", index_col="Time")
df.index = pd.to_datetime(df.index)
df['Position'] = 0.0
for i in ['50','200']:
    df[f'SMA_{i}'] = ta.sma(df['Close'], length=int(i))
for row in df.iterrows():
    if row['SMA_50'] > row['SMA_200']:
        row['Position'] = 1.0
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 11
#       9     df[f'SMA_{i}'] = ta.sma(df['Close'], length=int(i))
#      10 for row in df.iterrows():
# ---> 11     if row['SMA_50'] > row['SMA_200']:
#      12         row['Position'] = 1.0
#      13     elif row['SMA_50'] < row['SMA_200']:
#
# TypeError: tuple indices must be integers or slices, not str
