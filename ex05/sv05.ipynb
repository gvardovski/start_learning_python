# %%
import pandas as pd
import pandas_ta as ta
import vectorbt as vbt

df = pd.read_csv("MSFT_1hour.csv", index_col="Time")
df.index = pd.to_datetime(df.index)
pf_rsi = {}
for i in ['7','14','21']:
    df[f'RSI_{i}'] = ta.rsi(df['Close'], length=int(i))

    entries = df[f'RSI_{i}'] < 30
    exits = df[f'RSI_{i}'] > 70

    pf = vbt.Portfolio.from_signals(
    entries = entries,
    exits = exits,
    open = df["Open"],
    close = df["Close"],
    high = df["High"],
    low = df["Low"],
    size = 1,
    size_type ="percent",
    fees=0.0035,
    slippage=0.2,
    init_cash=55000,
    freq ="1hour"
    )
    pf_rsi.update({f'RSI_{i}':pf})

# %%
pf_rsi['RSI_14'].stats()
# Out:
# Start                         2020-01-01 00:00:00+00:00
# End                           2025-09-26 23:00:00+00:00
# Period                                959 days 06:00:00
# Start Value                                     55000.0
# End Value                                      0.000003
# Total Return [%]                                 -100.0
# Benchmark Return [%]                         223.350333
# Max Gross Exposure [%]                            100.0
# Total Fees Paid                              954.747866
# Max Drawdown [%]                                  100.0
# Max Drawdown Duration                 956 days 15:00:00
# Total Trades                                         58
# Total Closed Trades                                  58
# Total Open Trades                                     0
# Open Trade PnL                                      0.0
# Win Rate [%]                                        0.0
# Best Trade [%]                               -28.451436
# Worst Trade [%]                              -44.737042
# Avg Winning Trade [%]                               NaN
# Avg Losing Trade [%]                         -33.430068
# Avg Winning Trade Duration                          NaT
# Avg Losing Trade Duration     4 days 14:43:26.896551724
# Profit Factor                                       0.0
# Expectancy                                  -948.275862
# Sharpe Ratio                                  -6.458461
# Calmar Ratio                                  -0.999872
# Omega Ratio                                    0.350608
# Sortino Ratio                                  -6.54305
# dtype: object

# %%
pf_rsi['RSI_14'].plot()
# Out:
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': '#1f77b4'},
#               'name': 'Close',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '8f38e68b-c82c-4122-bc38-57f16202c85e',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('MzMzMzO7Y0CPwvUoXN9jQNejcD0K32' ... 'A9Ctfjf0AfhetRuOZ/QKjGSzeJ5n9A'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'customdata': {'bdata': ('AAAAAAAAAAAOYRlcgFhyQAAv8OOD+m' ... 'AAAACAXEA+Y4IFMF9KPgDP2+sdglE+'),
#                              'dtype': 'f8',
#                              'shape': '58, 3'},
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '1',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-up'},
#               'mode': 'markers',
#               'name': 'Buy',
#               'type': 'scatter',
#               'uid': 'a3db3311-4ba1-4962-86ae-aa2f546c228b',
#               'x': array([Timestamp('2020-01-07 23:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-24 18:00:00+0000', tz='UTC'),
#                           Timestamp('2020-02-20 16:00:00+0000', tz='UTC'),
#                           Timestamp('2020-04-21 13:00:00+0000', tz='UTC'),
#                           Timestamp('2020-05-12 19:00:00+0000', tz='UTC'),
#                           Timestamp('2020-05-27 13:00:00+0000', tz='UTC'),
#                           Timestamp('2020-06-11 19:00:00+0000', tz='UTC'),
#                           Timestamp('2020-06-24 15:00:00+0000', tz='UTC'),
#                           Timestamp('2020-07-13 19:00:00+0000', tz='UTC'),
#                           Timestamp('2020-07-24 08:00:00+0000', tz='UTC'),
#                           Timestamp('2020-08-10 13:00:00+0000', tz='UTC'),
#                           Timestamp('2020-09-03 14:00:00+0000', tz='UTC'),
#                           Timestamp('2020-10-02 11:00:00+0000', tz='UTC'),
#                           Timestamp('2020-10-15 08:00:00+0000', tz='UTC'),
#                           Timestamp('2020-11-10 15:00:00+0000', tz='UTC'),
#                           Timestamp('2020-12-30 20:00:00+0000', tz='UTC'),
#                           Timestamp('2021-02-22 09:00:00+0000', tz='UTC'),
#                           Timestamp('2021-04-27 20:00:00+0000', tz='UTC'),
#                           Timestamp('2021-05-10 19:00:00+0000', tz='UTC'),
#                           Timestamp('2021-05-19 08:00:00+0000', tz='UTC'),
#                           Timestamp('2021-06-02 08:00:00+0000', tz='UTC'),
#                           Timestamp('2021-07-19 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-07-27 16:00:00+0000', tz='UTC'),
#                           Timestamp('2021-08-10 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-08-19 08:00:00+0000', tz='UTC'),
#                           Timestamp('2021-08-26 19:00:00+0000', tz='UTC'),
#                           Timestamp('2021-09-07 13:00:00+0000', tz='UTC'),
#                           Timestamp('2021-09-20 08:00:00+0000', tz='UTC'),
#                           Timestamp('2021-11-10 16:00:00+0000', tz='UTC'),
#                           Timestamp('2021-11-23 15:00:00+0000', tz='UTC'),
#                           Timestamp('2021-12-14 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-12-31 15:00:00+0000', tz='UTC'),
#                           Timestamp('2022-01-13 17:00:00+0000', tz='UTC'),
#                           Timestamp('2022-01-24 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-02-10 23:00:00+0000', tz='UTC'),
#                           Timestamp('2022-04-06 08:00:00+0000', tz='UTC'),
#                           Timestamp('2022-04-22 15:00:00+0000', tz='UTC'),
#                           Timestamp('2022-05-05 15:00:00+0000', tz='UTC'),
#                           Timestamp('2022-06-09 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-06-28 15:00:00+0000', tz='UTC'),
#                           Timestamp('2022-07-12 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-07-26 13:00:00+0000', tz='UTC'),
#                           Timestamp('2022-08-19 08:00:00+0000', tz='UTC'),
#                           Timestamp('2022-09-13 12:00:00+0000', tz='UTC'),
#                           Timestamp('2022-10-07 13:00:00+0000', tz='UTC'),
#                           Timestamp('2022-10-25 21:00:00+0000', tz='UTC'),
#                           Timestamp('2022-11-28 17:00:00+0000', tz='UTC'),
#                           Timestamp('2022-12-06 16:00:00+0000', tz='UTC'),
#                           Timestamp('2022-12-15 16:00:00+0000', tz='UTC'),
#                           Timestamp('2023-01-04 14:00:00+0000', tz='UTC'),
#                           Timestamp('2023-01-19 11:00:00+0000', tz='UTC'),
#                           Timestamp('2023-02-10 09:00:00+0000', tz='UTC'),
#                           Timestamp('2023-02-16 14:00:00+0000', tz='UTC'),
#                           Timestamp('2023-03-28 14:00:00+0000', tz='UTC'),
#                           Timestamp('2023-04-06 09:00:00+0000', tz='UTC'),
#                           Timestamp('2023-04-11 14:00:00+0000', tz='UTC'),
#                           Timestamp('2023-04-24 15:00:00+0000', tz='UTC'),
#                           Timestamp('2023-05-23 18:00:00+0000', tz='UTC')], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('16NwPQpXZ0BuEoPAysloQB1aZDvff2' ... 'DeAjV1QMHKoUW283RATrSrkPK1d0A='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'customdata': {'bdata': ('AAAAAAAA8D8OYRlcgFhyQOjZLe9nn2' ... 'AAAADAXEA+Y4IFMF9KPtlHQi21a0g+'),
#                              'dtype': 'f8',
#                              'shape': '58, 3'},
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '2',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-down'},
#               'mode': 'markers',
#               'name': 'Sell',
#               'type': 'scatter',
#               'uid': '83cd5691-a0d7-4ce9-83bb-1181b0ce006a',
#               'x': array([Timestamp('2020-01-09 13:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-28 21:00:00+0000', tz='UTC'),
#                           Timestamp('2020-03-25 08:00:00+0000', tz='UTC'),
#                           Timestamp('2020-04-29 20:00:00+0000', tz='UTC'),
#                           Timestamp('2020-05-18 11:00:00+0000', tz='UTC'),
#                           Timestamp('2020-06-10 13:00:00+0000', tz='UTC'),
#                           Timestamp('2020-06-19 12:00:00+0000', tz='UTC'),
#                           Timestamp('2020-06-30 19:00:00+0000', tz='UTC'),
#                           Timestamp('2020-07-20 15:00:00+0000', tz='UTC'),
#                           Timestamp('2020-08-03 08:00:00+0000', tz='UTC'),
#                           Timestamp('2020-08-20 18:00:00+0000', tz='UTC'),
#                           Timestamp('2020-09-23 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-10-09 13:00:00+0000', tz='UTC'),
#                           Timestamp('2020-11-03 15:00:00+0000', tz='UTC'),
#                           Timestamp('2020-12-14 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-01-19 23:00:00+0000', tz='UTC'),
#                           Timestamp('2021-03-16 13:00:00+0000', tz='UTC'),
#                           Timestamp('2021-05-07 12:00:00+0000', tz='UTC'),
#                           Timestamp('2021-05-14 13:00:00+0000', tz='UTC'),
#                           Timestamp('2021-05-20 15:00:00+0000', tz='UTC'),
#                           Timestamp('2021-06-04 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-07-22 11:00:00+0000', tz='UTC'),
#                           Timestamp('2021-08-05 19:00:00+0000', tz='UTC'),
#                           Timestamp('2021-08-13 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-08-20 12:00:00+0000', tz='UTC'),
#                           Timestamp('2021-08-30 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-09-14 22:00:00+0000', tz='UTC'),
#                           Timestamp('2021-10-06 20:00:00+0000', tz='UTC'),
#                           Timestamp('2021-11-12 16:00:00+0000', tz='UTC'),
#                           Timestamp('2021-12-07 09:00:00+0000', tz='UTC'),
#                           Timestamp('2021-12-22 15:00:00+0000', tz='UTC'),
#                           Timestamp('2022-01-12 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-01-19 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-02-09 20:00:00+0000', tz='UTC'),
#                           Timestamp('2022-03-16 08:00:00+0000', tz='UTC'),
#                           Timestamp('2022-04-20 11:00:00+0000', tz='UTC'),
#                           Timestamp('2022-05-04 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-05-26 17:00:00+0000', tz='UTC'),
#                           Timestamp('2022-06-15 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-07-06 18:00:00+0000', tz='UTC'),
#                           Timestamp('2022-07-20 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-07-27 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-09-09 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-10-03 18:00:00+0000', tz='UTC'),
#                           Timestamp('2022-10-17 23:00:00+0000', tz='UTC'),
#                           Timestamp('2022-11-07 15:00:00+0000', tz='UTC'),
#                           Timestamp('2022-11-30 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-12-12 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-12-29 16:00:00+0000', tz='UTC'),
#                           Timestamp('2023-01-09 17:00:00+0000', tz='UTC'),
#                           Timestamp('2023-01-20 16:00:00+0000', tz='UTC'),
#                           Timestamp('2023-02-13 14:00:00+0000', tz='UTC'),
#                           Timestamp('2023-03-03 14:00:00+0000', tz='UTC'),
#                           Timestamp('2023-03-30 09:00:00+0000', tz='UTC'),
#                           Timestamp('2023-04-06 19:00:00+0000', tz='UTC'),
#                           Timestamp('2023-04-13 19:00:00+0000', tz='UTC'),
#                           Timestamp('2023-04-25 21:00:00+0000', tz='UTC'),
#                           Timestamp('2023-05-26 14:00:00+0000', tz='UTC')], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('r0fhehQuYEBYObTIdp5gQIxs5/upsV' ... 'EIrPxsQBBYObTIdm1A8KfGSzeJcEA='),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'customdata': {'bdata': ('AAAAAAAAAAAAAAAAAAAAAHLejj6SvN' ... 'AAAIBMQD7+GMOeHbi+MPSvgQq/078='),
#                              'dtype': 'f8',
#                              'shape': '58, 4'},
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '3',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'opacity': {'bdata': ('ykPDSKPU6D8kiaUEAoDpP83MzMzMzO' ... 'JWWB7pP0EEVXwyiug/NxdMtD616D8='),
#                                      'dtype': 'f8'},
#                          'size': {'bdata': ('s7O+df/FHkBaxlHwGYEgQCysFmx7Ay' ... 'g/G7wfQDErIstwzR1A9E8PUC1dHkA='),
#                                   'dtype': 'f8'},
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Loss',
#               'type': 'scatter',
#               'uid': '20c16b22-26eb-4e2b-8367-c701e25631c9',
#               'x': array([Timestamp('2020-01-09 13:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-28 21:00:00+0000', tz='UTC'),
#                           Timestamp('2020-03-25 08:00:00+0000', tz='UTC'),
#                           Timestamp('2020-04-29 20:00:00+0000', tz='UTC'),
#                           Timestamp('2020-05-18 11:00:00+0000', tz='UTC'),
#                           Timestamp('2020-06-10 13:00:00+0000', tz='UTC'),
#                           Timestamp('2020-06-19 12:00:00+0000', tz='UTC'),
#                           Timestamp('2020-06-30 19:00:00+0000', tz='UTC'),
#                           Timestamp('2020-07-20 15:00:00+0000', tz='UTC'),
#                           Timestamp('2020-08-03 08:00:00+0000', tz='UTC'),
#                           Timestamp('2020-08-20 18:00:00+0000', tz='UTC'),
#                           Timestamp('2020-09-23 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-10-09 13:00:00+0000', tz='UTC'),
#                           Timestamp('2020-11-03 15:00:00+0000', tz='UTC'),
#                           Timestamp('2020-12-14 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-01-19 23:00:00+0000', tz='UTC'),
#                           Timestamp('2021-03-16 13:00:00+0000', tz='UTC'),
#                           Timestamp('2021-05-07 12:00:00+0000', tz='UTC'),
#                           Timestamp('2021-05-14 13:00:00+0000', tz='UTC'),
#                           Timestamp('2021-05-20 15:00:00+0000', tz='UTC'),
#                           Timestamp('2021-06-04 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-07-22 11:00:00+0000', tz='UTC'),
#                           Timestamp('2021-08-05 19:00:00+0000', tz='UTC'),
#                           Timestamp('2021-08-13 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-08-20 12:00:00+0000', tz='UTC'),
#                           Timestamp('2021-08-30 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-09-14 22:00:00+0000', tz='UTC'),
#                           Timestamp('2021-10-06 20:00:00+0000', tz='UTC'),
#                           Timestamp('2021-11-12 16:00:00+0000', tz='UTC'),
#                           Timestamp('2021-12-07 09:00:00+0000', tz='UTC'),
#                           Timestamp('2021-12-22 15:00:00+0000', tz='UTC'),
#                           Timestamp('2022-01-12 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-01-19 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-02-09 20:00:00+0000', tz='UTC'),
#                           Timestamp('2022-03-16 08:00:00+0000', tz='UTC'),
#                           Timestamp('2022-04-20 11:00:00+0000', tz='UTC'),
#                           Timestamp('2022-05-04 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-05-26 17:00:00+0000', tz='UTC'),
#                           Timestamp('2022-06-15 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-07-06 18:00:00+0000', tz='UTC'),
#                           Timestamp('2022-07-20 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-07-27 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-09-09 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-10-03 18:00:00+0000', tz='UTC'),
#                           Timestamp('2022-10-17 23:00:00+0000', tz='UTC'),
#                           Timestamp('2022-11-07 15:00:00+0000', tz='UTC'),
#                           Timestamp('2022-11-30 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-12-12 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-12-29 16:00:00+0000', tz='UTC'),
#                           Timestamp('2023-01-09 17:00:00+0000', tz='UTC'),
#                           Timestamp('2023-01-20 16:00:00+0000', tz='UTC'),
#                           Timestamp('2023-02-13 14:00:00+0000', tz='UTC'),
#                           Timestamp('2023-03-03 14:00:00+0000', tz='UTC'),
#                           Timestamp('2023-03-30 09:00:00+0000', tz='UTC'),
#                           Timestamp('2023-04-06 19:00:00+0000', tz='UTC'),
#                           Timestamp('2023-04-13 19:00:00+0000', tz='UTC'),
#                           Timestamp('2023-04-25 21:00:00+0000', tz='UTC'),
#                           Timestamp('2023-05-26 14:00:00+0000', tz='UTC')], dtype=object),
#               'xaxis': 'x2',
#               'y': {'bdata': ('WvDvPzUD1L9R4uTHUnfVv9TYSoa3od' ... '/IQaPUv+q+XAyRYdO/MPSvgQq/078='),
#                     'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'legendgroup': '4',
#               'line': {'color': '#7f7f7f'},
#               'name': 'Benchmark',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '1ed94a6b-bafa-4fca-900e-7160a7b6ff0d',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D9mAoxvUh3wPx0A0QEQHf' ... 'KbVAfcCUBt9y4wXd4JQLZv4/023glA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '5',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3ea93896-c5eb-4903-917e-11862f1bc2d2',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQEB'),
#                     'dtype': 'i1'},
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(255, 0, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '5',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ea95eb57-3ebd-417f-9d4b-2f41757e72d2',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D8AAAAAAADwPwAAAAAAAP' ... 'fvJG4u0D1Zp+8kbi7QPVmn7yRuLtA9'),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'legendgroup': '6',
#               'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'fbe24dc2-732b-4c6a-8a73-21831ae177fc',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D8AAAAAAADwPwAAAAAAAP' ... 'fvJG4u0D1Zp+8kbi7QPVmn7yRuLtA9'),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '5',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0597ea87-6646-40db-a825-b5e10d0bb928',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQEB'),
#                     'dtype': 'i1'},
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Orders',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trade PnL',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.6527777777777777,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Cumulative Returns',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.3055555555555555,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 960,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.0416666666666667,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 0,
#                            'y1': 0,
#                            'yref': 'y2'},
#                           {'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y3'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 750,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0], 'title': {'text': 'Index'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.6944444444444444, 1.0], 'title': {'text': 'Price'}},
#                'yaxis2': {'anchor': 'x2',
#                           'domain': [0.3472222222222222, 0.6527777777777777],
#                           'tickformat': '.2%',
#                           'title': {'text': 'Trade PnL'}},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 0.3055555555555555], 'title': {'text': 'Cumulative returns'}}}
# })

# %%
import pandas as pd
import pandas_ta as ta
import vectorbt as vbt

df = pd.read_csv("MSFT_1hour.csv", index_col="Time")
df.index = pd.to_datetime(df.index)
for i in ['50','200']:
    df[f'SMA_{i}'] = ta.sma(df['Close'], length=int(i))
entries = (df['SMA_50'] > df['SMA_200']) & (df['SMA_50'].shift(1) <= df['SMA_200'].shift(1))
exits = (df['SMA_50'] < df['SMA_200']) & (df['SMA_50'].shift(1) >= df['SMA_200'].shift(1))
pf = vbt.Portfolio.from_signals(
    entries = entries,
    exits = exits,
    open = df["Open"],
    close = df["Close"],
    high = df["High"],
    low = df["Low"],
    size = 1,
    size_type ="percent",
    fees=0.0035,
    slippage=0.2,
    init_cash=55000,
    freq ="1hour"
    )

# %%
pf.stats()
# Out:
# Start                         2020-01-01 00:00:00+00:00
# End                           2025-09-26 23:00:00+00:00
# Period                                959 days 06:00:00
# Start Value                                     55000.0
# End Value                                      0.000005
# Total Return [%]                                 -100.0
# Benchmark Return [%]                         223.350333
# Max Gross Exposure [%]                            100.0
# Total Fees Paid                             1008.566854
# Max Drawdown [%]                                  100.0
# Max Drawdown Duration                 946 days 15:00:00
# Total Trades                                         57
# Total Closed Trades                                  57
# Total Open Trades                                     0
# Open Trade PnL                                      0.0
# Win Rate [%]                                        0.0
# Best Trade [%]                               -23.469124
# Worst Trade [%]                              -39.028565
# Avg Winning Trade [%]                               NaN
# Avg Losing Trade [%]                         -33.466451
# Avg Winning Trade Duration                          NaT
# Avg Losing Trade Duration     8 days 11:23:09.473684210
# Profit Factor                                       0.0
# Expectancy                                  -964.912281
# Sharpe Ratio                                  -6.274558
# Calmar Ratio                                  -0.999853
# Omega Ratio                                    0.420225
# Sortino Ratio                                 -6.336198
# dtype: object

# %%
pf.plot()
# Out:
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': '#1f77b4'},
#               'name': 'Close',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '4353d47f-9d8a-4320-a1d6-f88f9da07282',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('MzMzMzO7Y0CPwvUoXN9jQNejcD0K32' ... 'A9Ctfjf0AfhetRuOZ/QKjGSzeJ5n9A'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'customdata': {'bdata': ('AAAAAAAAAAALURQcnkpwQAAv8OOD+m' ... 'AAAAAAXEA+qrXaCAxOPgDk5hy5O1o+'),
#                              'dtype': 'f8',
#                              'shape': '57, 3'},
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '1',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-up'},
#               'mode': 'markers',
#               'name': 'Buy',
#               'type': 'scatter',
#               'uid': 'cd862e79-60a0-4adf-8cf0-deb10f9c5018',
#               'x': array([Timestamp('2020-01-29 23:00:00+0000', tz='UTC'),
#                           Timestamp('2020-03-26 16:00:00+0000', tz='UTC'),
#                           Timestamp('2020-05-19 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-06-03 11:00:00+0000', tz='UTC'),
#                           Timestamp('2020-07-23 08:00:00+0000', tz='UTC'),
#                           Timestamp('2020-08-03 19:00:00+0000', tz='UTC'),
#                           Timestamp('2020-08-20 14:00:00+0000', tz='UTC'),
#                           Timestamp('2020-09-28 18:00:00+0000', tz='UTC'),
#                           Timestamp('2020-11-05 16:00:00+0000', tz='UTC'),
#                           Timestamp('2020-11-30 20:00:00+0000', tz='UTC'),
#                           Timestamp('2020-12-16 17:00:00+0000', tz='UTC'),
#                           Timestamp('2021-01-21 10:00:00+0000', tz='UTC'),
#                           Timestamp('2021-03-10 22:00:00+0000', tz='UTC'),
#                           Timestamp('2021-03-23 21:00:00+0000', tz='UTC'),
#                           Timestamp('2021-04-01 16:00:00+0000', tz='UTC'),
#                           Timestamp('2021-05-24 18:00:00+0000', tz='UTC'),
#                           Timestamp('2021-06-07 18:00:00+0000', tz='UTC'),
#                           Timestamp('2021-07-22 12:00:00+0000', tz='UTC'),
#                           Timestamp('2021-09-16 13:00:00+0000', tz='UTC'),
#                           Timestamp('2021-10-08 09:00:00+0000', tz='UTC'),
#                           Timestamp('2021-12-09 22:00:00+0000', tz='UTC'),
#                           Timestamp('2021-12-27 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-01-31 21:00:00+0000', tz='UTC'),
#                           Timestamp('2022-03-01 15:00:00+0000', tz='UTC'),
#                           Timestamp('2022-03-17 20:00:00+0000', tz='UTC'),
#                           Timestamp('2022-04-28 23:00:00+0000', tz='UTC'),
#                           Timestamp('2022-05-05 08:00:00+0000', tz='UTC'),
#                           Timestamp('2022-05-26 16:00:00+0000', tz='UTC'),
#                           Timestamp('2022-06-24 14:00:00+0000', tz='UTC'),
#                           Timestamp('2022-07-22 08:00:00+0000', tz='UTC'),
#                           Timestamp('2022-10-04 21:00:00+0000', tz='UTC'),
#                           Timestamp('2022-10-19 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-11-10 18:00:00+0000', tz='UTC'),
#                           Timestamp('2022-11-30 22:00:00+0000', tz='UTC'),
#                           Timestamp('2022-12-13 09:00:00+0000', tz='UTC'),
#                           Timestamp('2023-01-13 11:00:00+0000', tz='UTC'),
#                           Timestamp('2023-03-07 13:00:00+0000', tz='UTC'),
#                           Timestamp('2023-04-26 20:00:00+0000', tz='UTC'),
#                           Timestamp('2023-06-14 13:00:00+0000', tz='UTC'),
#                           Timestamp('2023-07-03 20:00:00+0000', tz='UTC'),
#                           Timestamp('2023-07-05 13:00:00+0000', tz='UTC'),
#                           Timestamp('2023-07-14 08:00:00+0000', tz='UTC'),
#                           Timestamp('2023-08-23 21:00:00+0000', tz='UTC'),
#                           Timestamp('2023-10-06 16:00:00+0000', tz='UTC'),
#                           Timestamp('2023-10-25 08:00:00+0000', tz='UTC'),
#                           Timestamp('2023-12-20 12:00:00+0000', tz='UTC'),
#                           Timestamp('2024-01-10 16:00:00+0000', tz='UTC'),
#                           Timestamp('2024-02-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2024-03-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2024-03-13 13:00:00+0000', tz='UTC'),
#                           Timestamp('2024-04-09 13:00:00+0000', tz='UTC'),
#                           Timestamp('2024-04-09 21:00:00+0000', tz='UTC'),
#                           Timestamp('2024-05-06 21:00:00+0000', tz='UTC'),
#                           Timestamp('2024-06-10 10:00:00+0000', tz='UTC'),
#                           Timestamp('2024-08-14 15:00:00+0000', tz='UTC'),
#                           Timestamp('2024-09-12 08:00:00+0000', tz='UTC'),
#                           Timestamp('2024-10-16 18:00:00+0000', tz='UTC')], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('m8QgsHJIakCjcD0K1xNnQC/dJAaB1W' ... 'f7qfFOf0CXbhKDwLp/QGZmZmZmLn9A'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'customdata': {'bdata': ('AAAAAAAA8D8LURQcnkpwQIG684LvWF' ... 'AAAABAXEA+qrXaCAxOPraP1E4SZ1E+'),
#                              'dtype': 'f8',
#                              'shape': '57, 3'},
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '2',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-down'},
#               'mode': 'markers',
#               'name': 'Sell',
#               'type': 'scatter',
#               'uid': '9f612525-a210-4822-aec3-ff76087cc2c9',
#               'x': array([Timestamp('2020-02-24 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-05-15 15:00:00+0000', tz='UTC'),
#                           Timestamp('2020-05-27 13:00:00+0000', tz='UTC'),
#                           Timestamp('2020-07-16 15:00:00+0000', tz='UTC'),
#                           Timestamp('2020-07-23 23:00:00+0000', tz='UTC'),
#                           Timestamp('2020-08-12 18:00:00+0000', tz='UTC'),
#                           Timestamp('2020-09-08 13:00:00+0000', tz='UTC'),
#                           Timestamp('2020-10-22 11:00:00+0000', tz='UTC'),
#                           Timestamp('2020-11-18 21:00:00+0000', tz='UTC'),
#                           Timestamp('2020-12-10 17:00:00+0000', tz='UTC'),
#                           Timestamp('2021-01-05 12:00:00+0000', tz='UTC'),
#                           Timestamp('2021-02-19 22:00:00+0000', tz='UTC'),
#                           Timestamp('2021-03-22 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-03-29 09:00:00+0000', tz='UTC'),
#                           Timestamp('2021-04-29 08:00:00+0000', tz='UTC'),
#                           Timestamp('2021-06-03 21:00:00+0000', tz='UTC'),
#                           Timestamp('2021-07-21 19:00:00+0000', tz='UTC'),
#                           Timestamp('2021-09-07 18:00:00+0000', tz='UTC'),
#                           Timestamp('2021-09-21 09:00:00+0000', tz='UTC'),
#                           Timestamp('2021-11-26 16:00:00+0000', tz='UTC'),
#                           Timestamp('2021-12-16 18:00:00+0000', tz='UTC'),
#                           Timestamp('2022-01-05 15:00:00+0000', tz='UTC'),
#                           Timestamp('2022-02-11 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-03-07 21:00:00+0000', tz='UTC'),
#                           Timestamp('2022-04-07 16:00:00+0000', tz='UTC'),
#                           Timestamp('2022-05-04 12:00:00+0000', tz='UTC'),
#                           Timestamp('2022-05-06 11:00:00+0000', tz='UTC'),
#                           Timestamp('2022-06-10 17:00:00+0000', tz='UTC'),
#                           Timestamp('2022-07-13 13:00:00+0000', tz='UTC'),
#                           Timestamp('2022-08-22 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-10-10 22:00:00+0000', tz='UTC'),
#                           Timestamp('2022-10-28 10:00:00+0000', tz='UTC'),
#                           Timestamp('2022-11-30 15:00:00+0000', tz='UTC'),
#                           Timestamp('2022-12-08 17:00:00+0000', tz='UTC'),
#                           Timestamp('2022-12-19 15:00:00+0000', tz='UTC'),
#                           Timestamp('2023-02-21 10:00:00+0000', tz='UTC'),
#                           Timestamp('2023-04-21 16:00:00+0000', tz='UTC'),
#                           Timestamp('2023-06-09 11:00:00+0000', tz='UTC'),
#                           Timestamp('2023-06-27 12:00:00+0000', tz='UTC'),
#                           Timestamp('2023-07-05 11:00:00+0000', tz='UTC'),
#                           Timestamp('2023-07-11 15:00:00+0000', tz='UTC'),
#                           Timestamp('2023-07-26 18:00:00+0000', tz='UTC'),
#                           Timestamp('2023-09-19 16:00:00+0000', tz='UTC'),
#                           Timestamp('2023-10-24 14:00:00+0000', tz='UTC'),
#                           Timestamp('2023-12-04 18:00:00+0000', tz='UTC'),
#                           Timestamp('2024-01-04 00:00:00+0000', tz='UTC'),
#                           Timestamp('2024-02-15 19:00:00+0000', tz='UTC'),
#                           Timestamp('2024-02-28 10:00:00+0000', tz='UTC'),
#                           Timestamp('2024-03-07 12:00:00+0000', tz='UTC'),
#                           Timestamp('2024-04-01 09:00:00+0000', tz='UTC'),
#                           Timestamp('2024-04-09 16:00:00+0000', tz='UTC'),
#                           Timestamp('2024-04-16 09:00:00+0000', tz='UTC'),
#                           Timestamp('2024-05-31 13:00:00+0000', tz='UTC'),
#                           Timestamp('2024-07-15 15:00:00+0000', tz='UTC'),
#                           Timestamp('2024-08-27 12:00:00+0000', tz='UTC'),
#                           Timestamp('2024-09-27 14:00:00+0000', tz='UTC'),
#                           Timestamp('2024-11-01 16:00:00+0000', tz='UTC')], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('r0fhehQuYUDLoUW2881hQAMrhxbZzm' ... 'MLQQ6edEC0yHa+n4p1QGzsEtVbr3RA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'},
#              {'customdata': {'bdata': ('AAAAAAAAAAAAAAAAAAAAALdc7jHy2N' ... 'AAAAAATECzX0B+Xg3EvszKiCuU6tW/'),
#                              'dtype': 'f8',
#                              'shape': '57, 4'},
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '3',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'opacity': {'bdata': ('QMfHaX6f6z8AAAAAAADoPwlop5WUDO' ... 'qDKiZ56z+6P8cou9jqP2bmTxX2Uus/'),
#                                      'dtype': 'f8'},
#                          'size': {'bdata': ('9RsVMXkBJUAAAAAAAAAcQNKz32Jp1C' ... 'mevVO3JEAsGFhqIYEjQBHaWPR7bSRA'),
#                                   'dtype': 'f8'},
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Loss',
#               'type': 'scatter',
#               'uid': '680adae2-d5a9-464c-abe7-9b221e475bbf',
#               'x': array([Timestamp('2020-02-24 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-05-15 15:00:00+0000', tz='UTC'),
#                           Timestamp('2020-05-27 13:00:00+0000', tz='UTC'),
#                           Timestamp('2020-07-16 15:00:00+0000', tz='UTC'),
#                           Timestamp('2020-07-23 23:00:00+0000', tz='UTC'),
#                           Timestamp('2020-08-12 18:00:00+0000', tz='UTC'),
#                           Timestamp('2020-09-08 13:00:00+0000', tz='UTC'),
#                           Timestamp('2020-10-22 11:00:00+0000', tz='UTC'),
#                           Timestamp('2020-11-18 21:00:00+0000', tz='UTC'),
#                           Timestamp('2020-12-10 17:00:00+0000', tz='UTC'),
#                           Timestamp('2021-01-05 12:00:00+0000', tz='UTC'),
#                           Timestamp('2021-02-19 22:00:00+0000', tz='UTC'),
#                           Timestamp('2021-03-22 14:00:00+0000', tz='UTC'),
#                           Timestamp('2021-03-29 09:00:00+0000', tz='UTC'),
#                           Timestamp('2021-04-29 08:00:00+0000', tz='UTC'),
#                           Timestamp('2021-06-03 21:00:00+0000', tz='UTC'),
#                           Timestamp('2021-07-21 19:00:00+0000', tz='UTC'),
#                           Timestamp('2021-09-07 18:00:00+0000', tz='UTC'),
#                           Timestamp('2021-09-21 09:00:00+0000', tz='UTC'),
#                           Timestamp('2021-11-26 16:00:00+0000', tz='UTC'),
#                           Timestamp('2021-12-16 18:00:00+0000', tz='UTC'),
#                           Timestamp('2022-01-05 15:00:00+0000', tz='UTC'),
#                           Timestamp('2022-02-11 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-03-07 21:00:00+0000', tz='UTC'),
#                           Timestamp('2022-04-07 16:00:00+0000', tz='UTC'),
#                           Timestamp('2022-05-04 12:00:00+0000', tz='UTC'),
#                           Timestamp('2022-05-06 11:00:00+0000', tz='UTC'),
#                           Timestamp('2022-06-10 17:00:00+0000', tz='UTC'),
#                           Timestamp('2022-07-13 13:00:00+0000', tz='UTC'),
#                           Timestamp('2022-08-22 19:00:00+0000', tz='UTC'),
#                           Timestamp('2022-10-10 22:00:00+0000', tz='UTC'),
#                           Timestamp('2022-10-28 10:00:00+0000', tz='UTC'),
#                           Timestamp('2022-11-30 15:00:00+0000', tz='UTC'),
#                           Timestamp('2022-12-08 17:00:00+0000', tz='UTC'),
#                           Timestamp('2022-12-19 15:00:00+0000', tz='UTC'),
#                           Timestamp('2023-02-21 10:00:00+0000', tz='UTC'),
#                           Timestamp('2023-04-21 16:00:00+0000', tz='UTC'),
#                           Timestamp('2023-06-09 11:00:00+0000', tz='UTC'),
#                           Timestamp('2023-06-27 12:00:00+0000', tz='UTC'),
#                           Timestamp('2023-07-05 11:00:00+0000', tz='UTC'),
#                           Timestamp('2023-07-11 15:00:00+0000', tz='UTC'),
#                           Timestamp('2023-07-26 18:00:00+0000', tz='UTC'),
#                           Timestamp('2023-09-19 16:00:00+0000', tz='UTC'),
#                           Timestamp('2023-10-24 14:00:00+0000', tz='UTC'),
#                           Timestamp('2023-12-04 18:00:00+0000', tz='UTC'),
#                           Timestamp('2024-01-04 00:00:00+0000', tz='UTC'),
#                           Timestamp('2024-02-15 19:00:00+0000', tz='UTC'),
#                           Timestamp('2024-02-28 10:00:00+0000', tz='UTC'),
#                           Timestamp('2024-03-07 12:00:00+0000', tz='UTC'),
#                           Timestamp('2024-04-01 09:00:00+0000', tz='UTC'),
#                           Timestamp('2024-04-09 16:00:00+0000', tz='UTC'),
#                           Timestamp('2024-04-16 09:00:00+0000', tz='UTC'),
#                           Timestamp('2024-05-31 13:00:00+0000', tz='UTC'),
#                           Timestamp('2024-07-15 15:00:00+0000', tz='UTC'),
#                           Timestamp('2024-08-27 12:00:00+0000', tz='UTC'),
#                           Timestamp('2024-09-27 14:00:00+0000', tz='UTC'),
#                           Timestamp('2024-11-01 16:00:00+0000', tz='UTC')], dtype=object),
#               'xaxis': 'x2',
#               'y': {'bdata': ('O7i1Q1qJ1r+wYsDHXArOv+e/X66pa9' ... 'ITjs051r/DEJdDAO3Uv8zKiCuU6tW/'),
#                     'dtype': 'f8'},
#               'yaxis': 'y2'},
#              {'legendgroup': '4',
#               'line': {'color': '#7f7f7f'},
#               'name': 'Benchmark',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '177afad2-bbf1-433c-a234-dd50ed644405',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D9mAoxvUh3wPx0A0QEQHf' ... 'KbVAfcCUBt9y4wXd4JQLZv4/023glA'),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '5',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '341b3476-83ad-4560-b06b-eaaeb8e926c9',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQEB'),
#                     'dtype': 'i1'},
#               'yaxis': 'y3'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(255, 0, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '5',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c34975a9-6af9-436a-9917-7d34c776fe03',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D8AAAAAAADwPwAAAAAAAP' ... 'q1Ie4P1z3UGrUh7g/XPdQatSHuD9c9'),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'legendgroup': '6',
#               'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c19476fb-5c8a-43d6-a455-36ef14d86043',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AAAAAAAA8D8AAAAAAADwPwAAAAAAAP' ... 'q1Ie4P1z3UGrUh7g/XPdQatSHuD9c9'),
#                     'dtype': 'f8'},
#               'yaxis': 'y3'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '5',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '3224ea3b-948a-4fd1-99c5-c47b373e4829',
#               'x': array([Timestamp('2020-01-01 00:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 09:00:00+0000', tz='UTC'),
#                           Timestamp('2020-01-02 10:00:00+0000', tz='UTC'), ...,
#                           Timestamp('2025-09-26 21:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 22:00:00+0000', tz='UTC'),
#                           Timestamp('2025-09-26 23:00:00+0000', tz='UTC')],
#                          shape=(23022,), dtype=object),
#               'xaxis': 'x3',
#               'y': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQEBAQEBAQ' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQEB'),
#                     'dtype': 'i1'},
#               'yaxis': 'y3'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Orders',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trade PnL',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.6527777777777777,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Cumulative Returns',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.3055555555555555,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 960,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.0416666666666667,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 0,
#                            'y1': 0,
#                            'yref': 'y2'},
#                           {'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y3'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 750,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0], 'matches': 'x3', 'showticklabels': False},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0], 'title': {'text': 'Index'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.6944444444444444, 1.0], 'title': {'text': 'Price'}},
#                'yaxis2': {'anchor': 'x2',
#                           'domain': [0.3472222222222222, 0.6527777777777777],
#                           'tickformat': '.2%',
#                           'title': {'text': 'Trade PnL'}},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.0, 0.3055555555555555], 'title': {'text': 'Cumulative returns'}}}
# })
